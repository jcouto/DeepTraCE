# %%
from deeptrace import *
stack = BrainStack(channel_folders=['../../sampledata/210723_NAc326F_488_s3_0_8x_13-31-25/',
                   '../../sampledata/210723_NAc326F_640_s3_0_8x_11-50-51/'])
trailmap_channel = 1
stack.set_active_channels([trailmap_channel])

# %%
files = stack.channel_files[trailmap_channel]
from tqdm.notebook import tqdm
pbar = tqdm()
models = trailmap_list_models()
model_path = models[4]
trailmap_segment_tif_files(model_path, files,pbar = pbar)
# Out:
# 0it [00:00, ?it/s]
# Loading TRAILMAP network and model.
# Using model weight denardo_trapmodel4.hdf5

# %%
stack = BrainStack(channel_folders=['../../sampledata/denardo_trapmodel4_seg-210723_NAc326F_640_s3_0_8x_11-50-51'])
stack.downsample(pbar = pbar)

# %%
# now use 3 colors to visualize
stack = BrainStack(channel_folders=['../../sampledata/denardo_trapmodel4_seg-210723_NAc326F_640_s3_0_8x_11-50-51',
                                   '../../sampledata/210723_NAc326F_488_s3_0_8x_13-31-25/',
                                    '../../sampledata/210723_NAc326F_640_s3_0_8x_11-50-51/'],downsample = True)
# Out:
# Downsampling channel 0.

# %%
import numpy as np
dd = np.stack(stack.downsampled_data)
rgb = dd.transpose([1,2,3,0])

import pylab as plt
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Milner\AppData\Local\Temp\ipykernel_16592\3907816014.py", line 5, in <module>
#     import pylab as plt
# ModuleNotFoundError: No module named 'pylab'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ModuleNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Milner\AppData\Local\Temp\ipykernel_16592\3907816014.py", line 5, in <module>
#     import pylab as plt
# ModuleNotFoundError: No module named 'pylab'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ModuleNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Milner\AppData\Local\Temp\ipykernel_16592\3907816014.py", line 5, in <module>
#     import pylab as plt
# ModuleNotFoundError: No module named 'pylab'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ModuleNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\users\Milner\anaconda3\envs\trailmap_env\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
